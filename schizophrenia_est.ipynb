# %% [markdown]
# <a href="https://colab.research.google.com/github/Whoami666/HSE_Lab/blob/main/schizophrenia_est.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Github connect

# %%
from getpass import getpass

# %%
# !git init
username = 'Whoami666'
password = getpass('Password:')

# !git config --global user.email '$whoamilovel2sh@gmail.com'
# !git config --global user.name '$Whoami666'
link = f'https://{username}:{password}@github.com/{username}/HSE_Lab.git'
# !git remote add origin link
# !ls
# Out:
# Reinitialized existing Git repository in /content/.git/
# Password:··········
# fatal: remote origin already exists.
# sample_data

# %%
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jan  5 14:34 sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git add -A #schizophrenia_est.ipynb
# !git commit -m 'loaded data'  # commit in Colab
# !git push --set-upstream origin master
# Out:
# [master (root-commit) 279d6d7] loaded data
#  19 files changed, 50860 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.01.05/14.32.18.784307.log
#  create mode 100644 .config/logs/2023.01.05/14.32.48.311993.log
#  create mode 100644 .config/logs/2023.01.05/14.33.16.757082.log
#  create mode 100644 .config/logs/2023.01.05/14.33.30.524625.log
#  create mode 100644 .config/logs/2023.01.05/14.34.00.192801.log
#  create mode 100644 .config/logs/2023.01.05/14.34.01.063009.log
#  create mode 100755 sample_data/README.md
#  create mode 100755 sample_data/anscombe.json
#  create mode 100644 sample_data/california_housing_test.csv
# ...

# %% [markdown]
# UnZipping

# %%
import pandas as pd
from zipfile import ZipFile
from google.colab import files
import zipfile
from google.colab import drive

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/copy_psychiatric_disorders_data.zip
# Out:
# Archive:  /content/drive/MyDrive/copy_psychiatric_disorders_data.zip
#    creating: psychiatric_disorders_data.ML/
#   inflating: __MACOSX/._psychiatric_disorders_data.ML
#    creating: psychiatric_disorders_data.ML/reading/
#   inflating: __MACOSX/psychiatric_disorders_data.ML/._reading
#   inflating: psychiatric_disorders_data.ML/.DS_Store
#   inflating: __MACOSX/psychiatric_disorders_data.ML/._.DS_Store
#   inflating: psychiatric_disorders_data.ML/PsychiatricDiscourse_participant.data.xlsx
#   inflating: __MACOSX/psychiatric_disorders_data.ML/._PsychiatricDiscourse_participant.data.xlsx
#    creating: psychiatric_disorders_data.ML/information about the data/
#   inflating: __MACOSX/psychiatric_disorders_data.ML/._information about the data
#    creating: psychiatric_disorders_data.ML/wav files/
#   inflating: __MACOSX/psychiatric_disorders_data.ML/._wav files
#   inflating: psychiatric_disorders_data.ML/reading/Voleti_etal_2020_review.pdf
# ...

# %%
files.download('__MACOSX/psychiatric_disorders_data.ML/information about the data/Stimuli/._1-sportsman.pdf')

# %%
files.download('') 
files.download('') 
files.download('') 
files.download('__MACOSX/psychiatric_disorders_data.ML/information about the data/Stimuli/._3-table.pdf') 
files.download('__MACOSX/psychiatric_disorders_data.ML/information about the data/Stimuli/._3-table.pdf')

# %% [markdown]
# Librosa

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
signal, sr = librosa.load(librosa.util.example('brahms'))

# %%
plt.figure(figsize=(20, 5))
librosa.display.waveshow(signal, sr=sr)
plt.title('Waveplot', fontdict=dict(size=18))
plt.xlabel('Time', fontdict=dict(size=15))
plt.ylabel('Amplitude', fontdict=dict(size=15))
plt.show()

# %%
# Compute root-mean-square (RMS) value for each frame,
# either from the audio samples y or from a spectrogram S.

rms = librosa.feature.rms(y=signal)

rms

# %%
from scipy.io import wavfile
samplerate, data = wavfile.read('/content/psychiatric_disorders_data.ML/wav files/PN-070-instr-1-bench.wav')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8236f2683832> in <module>
#       1 from scipy.io import wavfile
# ----> 2 samplerate, data = wavfile.read('/content/psychiatric_disorders_data.ML/wav files/PN-070-instr-1-bench.wav')
#
# /usr/local/lib/python3.8/dist-packages/scipy/io/wavfile.py in read(filename, mmap)
#     645         mmap = False
#     646     else:
# --> 647         fid = open(filename, 'rb')
#     648
#     649     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/psychiatric_disorders_data.ML/wav files/PN-070-instr-1-bench.wav'

# %% [markdown]
# PATIENT DATA

# %%
df = pd.read_excel('psychiatric_disorders_data.ML/PsychiatricDiscourse_participant.data.xlsx')   
df.head(1)
# Out:
#        ID    group             diagnosis     sex   age education.level  \
# 0  PD-001  patient  schizotypal.disorder  female  19.0       secondary
#
#    education.years  depression.symptoms  thought.disorder.symptoms
# 0               11                    1                          0

# %%
df.rename(columns={'education.level': 'education_lvl', 
                   'education.years': 'education_years',
                   'depression.symptoms': 'depression', 
                   'thought.disorder.symptoms': 'tds'}, inplace=True)
df.head(1)
# Out:
#        ID    group             diagnosis     sex   age education_lvl  \
# 0  PD-001  patient  schizotypal.disorder  female  19.0     secondary
#
#    education_years  depression  tds
# 0               11           1    0
